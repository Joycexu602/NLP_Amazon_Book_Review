# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

stop_words = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eeejo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eeejo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\eeejo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
review_data = pd.read_csv(r"C:\Users\eeejo\Downloads\review_data.csv")

# %%
book_description = review_data.drop_duplicates(subset = ['Title','description'])
book_description.head()
# Out:
#                                                 Title         User_id  \
# 0                      Its Only Art If Its Well Hung!   AVCGYZL8FQQTD
# 1                            Dr. Seuss: American Icon  A30TK6U7DNS82R
# 10              Wonderful Worship in Smaller Churches   AZ0IOBU20TBOP
# 14                      Whispers of the Wicked Saints  A3Q12RK71N74LB
# 46  Nation Dance: Religion, Identity and Cultural ...   AN9WUW5BG7M39
#
#               profileName review/helpfulness  review/score review/time  \
# 0   Jim of Oz "jim-of-oz"                7/7           4.0  1999-10-23
# 1           Kevin Killian              10/10           5.0  2004-09-21
# 10     Rev. Pamela Tinnin               8/10           5.0  2001-06-02
# 14            Book Reader               7/11           1.0  2005-05-26
# 46            Pink Noodle                1/1           5.0  2008-02-04
#
#                                    review/summary  \
# 0          Nice collection of Julie Strain images
# 1                               Really Enjoyed It
# 10  Outstanding Resource for Small Church Pastors
# 14                                       not good
# 46       interplay of traditions across Caribbean
#
#                                           review/text  \
# 0   This is only for Julie Strain fans. It's a col...
# 1   I don't care much for Dr. Seuss but after read...
# 10  I just finished the book, &quot;Wonderful Wors...
# 14  I bought this book because I read some glowing...
# 46  from publisher:Addresses the interplay of dive...
#
#                                           description          authors  \
# 0                                             Unknown     Julie Strain
# 1   Philip Nel takes a fascinating look into the k...       Philip Nel
# 10  This resource includes twelve principles in un...     David R. Ray
# 14  Julia Thomas finds her life spinning out of co...  Veronica Haddon
# 46                                            Unknown      Edward Long
#
#     publisher publishedYear                 categories
# 0     Unknown        1996.0                    Fiction
# 1   A&C Black        2005.0  Biography & Autobiography
# 10    Unknown        2000.0                   Religion
# 14  iUniverse        2005.0                    Fiction
# 46    Unknown        2003.0                     Others

# %%
book_description.shape
# Out:
# (212397, 13)

# %%
STOPWORDS = set(stop_words)

PATTERN_S = re.compile("\'s")  # matches `'s` from text
PATTERN_RN = re.compile("\\r\\n") #matches `\r` and `\n`
PATTERN_PUNC = re.compile(r"[^\w\s]") # matches all non 0-9 A-z whitespace


def clean_text(text):
    """
    Series of cleaning. String to lower case, remove non words characters and numbers (punctuation, curly brackets etc).
        text (str): input text
    return (str): modified initial text
    """
    text = text.lower()  # lowercase text
    # replace the matched string with ' '
    text = re.sub(PATTERN_S, ' ', text)
    text = re.sub(PATTERN_RN, ' ', text)
    text = re.sub(PATTERN_PUNC, ' ', text)
    return text

def tokenizer(sentence, stopwords=STOPWORDS, lemmatize=True):
    stemmer = WordNetLemmatizer()
    tokens = [stemmer.lemmatize(w) for w in word_tokenize(sentence)]
    tokens = [w for w in tokens if (len(w) > 2 and len(w) < 200 and w not in stopwords)]
    return tokens

# %%
def extract_best_indices(m, topk, mask=None):
    """
    Use sum of the cosine distance over all tokens and return best mathes.
    m (np.array): cos matrix of shape (nb_in_tokens, nb_dict_tokens)
    topk (int): number of indices to return (from high to lowest in order)
    """
    # return the sum on all tokens of cosinus for each sentence
    if len(m.shape) > 1:
        cos_sim = np.mean(m, axis=0)
    else:
        cos_sim = m
    index = np.argsort(cos_sim)[::-1] # from highest idx to smallest score
    if mask is not None:
        assert mask.shape == m.shape
        mask = mask[index]
    else:
        mask = np.ones(len(cos_sim))
    mask = np.logical_or(cos_sim[index] != 0, mask) #eliminate 0 cosine distance
    best_index = index[mask][:topk]
    return best_index

def get_recommendations_tfidf(sentence, tfidf_mat):

    """
    Return the database sentences in order of highest cosine similarity relatively to each
    token of the target sentence.
    """
    # Embed the query sentence
    tokens_query = [str(tok) for tok in tokenizer(sentence)]
    embed_query = vectorizer.transform(tokens_query)
    # Create list with similarity between query and dataset
    mat = cosine_similarity(embed_query, tfidf_mat)
    # Best cosine distance for each token independantly
    best_index = extract_best_indices(mat, topk=20)
    return best_index

# %%
# Adapt stop words
token_stop = tokenizer(' '.join(stop_words), lemmatize=False)

# Fit TFIDF
vectorizer = TfidfVectorizer(stop_words=token_stop, tokenizer=tokenizer)
tfidf_mat = vectorizer.fit_transform(book_description['description'].values) # -> (num_sentences, num_vocabulary)
# Out:
# C:\Users\eeejo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
test_query = 'detective story'
best_index = get_recommendations_tfidf(test_query, tfidf_mat)

result = book_description[['Title', 'description']].iloc[best_index]
result
# Out:
#                                                      Title  \
# 389693   August is a Good Time for Killing: And Other B...
# 666089   British Women Mystery Writers: Six Authors of ...
# 693799   THE DRAMATIZED OLD TESTAMENT - Two Volume Set ...
# 891238             Twelve Mystery Stories (Oxford Twelves)
# 306547                                     The Early Fears
# 2175547  They're All Trying to Kill Me!: (Or How I Mana...
# 196641                                    a capital affair
# 293033   Easy True Stories: A Picture-Based Beginning R...
# 2651668              More True Stories: A Beginning Reader
# 2260115       True Stories in the News: A Beginning Reader
# 2631818                        It's a Pig World Cut There!
# 598746   The Rivals (Classic Books on Cassettes Collect...
# 2420939  The rivals of Sherlock Holmes : early detectiv...
# 1750528                                    The Bible Story
# 1463140                                    The Bible story
# 512943                        The Old Detective's Daughter
# 1575314                            Spirit Archives, Vol. 7
# 231798   The Jewish Story Finder: A Guide To 363 Tales ...
# 1919676  First Cases 3: New and Classic Tales of Detection
# 2523645  Fall of the House of Usher and Other Stories (...
#
#                                                description
# 389693          A collection of detective mystery stories.
# 666089   Many aspects of British detective fiction are ...
# 693799   Those of us hearing a "Well Told Story" may be...
# 891238   The field of detective fiction is vast, and Th...
# 306547   Features 39 of the author's short stories, inc...
# 2175547  The setting of the story takes place in the my...
# 196641   This story is not a story of the author, but t...
# 293033   A couple feels something moving inside their m...
# 2651668  A couple feels something moving inside their m...
# 2260115  A couple feels something moving inside their m...
# 2631818                                    Animal stories.
# 598746   This masterful collection of seventeen classic...
# 2420939  This masterful collection of seventeen classic...
# 1750528  The stories in this booklet are but a cross se...
# 1463140  The stories in this booklet are but a cross se...
# 512943   THE NUMBER ONE BESTSELLER. Detective Darnell d...
# 1575314  Collects stories from classic Spirit adventure...
# 231798   A subject guide to hundreds of Jewish stories,...
# 1919676  Famous detectives and careermaking cases fill ...
# 2523645  Six short stories written by the master of hor...
